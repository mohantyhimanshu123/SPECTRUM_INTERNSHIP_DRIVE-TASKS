# %%
#Import all the pre-requisite libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the csv file
df = pd.read_csv("student-math.csv", sep = ';')
## Here the most imp thing is te separator sep = ';'

# %% [markdown]
# #### DataFrame created

# %%
# Display the file and this is the dataframe
df.head(8)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# 1  ...      5        3      3     1     1      3        4   5   5   6
# 2  ...      4        3      2     2     3      3       10   7   8  10
# 3  ...      3        2      2     1     1      5        2  15  14  15
# 4  ...      4        3      2     1     2      5        4   6  10  10
# 5  ...      5        4      2     1     2      5       10  15  15  15
# 6  ...      4        4      4     1     1      3        0  12  12  11
# 7  ...      4        1      4     1     1      1        6   6   5   6
#
# [8 rows x 33 columns]

# %% [markdown]
# ### https://thispointer.com/pandas-read-csv-file-to-dataframe-with-custom-delimiter-in-python/

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ### Attributes for student-math.csv (Math course) dataset:
#
# 1 school - student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)<br>
# 2 sex - student's sex (binary: "F" - female or "M" - male)<br>
# 3 age - student's age (numeric: from 15 to 22)<br>
# 4 address - student's home address type (binary: "U" - urban or "R" - rural<br>
# 5 famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)<br>
# 6 Pstatus - parent's cohabitation status (binary: "T" - living together or "A" - apart)<br>
# 7 Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)<br>
# 8 Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)<br>
# 9 Mjob - mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")<br>
# 10 Fjob - father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")<br>
# 11 reason - reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")<br>
# 12 guardian - student's guardian (nominal: "mother", "father" or "other")<br>
# 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)<br>
# 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)<br>
# 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)<br>
# 16 schoolsup - extra educational support (binary: yes or no)<br>
# 17 famsup - family educational support (binary: yes or no)<br>
# 18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)<br>
# 19 activities - extra-curricular activities (binary: yes or no)<br>
# 20 nursery - attended nursery school (binary: yes or no)<br>
# 21 higher - wants to take higher education (binary: yes or no)<br>
# 22 internet - Internet access at home (binary: yes or no)<br>
# 23 romantic - with a romantic relationship (binary: yes or no)<br>
# 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)<br>
# 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)<br>
# 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)<br>
# 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)<br>
# 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)<br>
# 29 health - current health status (numeric: from 1 - very bad to 5 - very good)<br>
# 30 absences - number of school absences (numeric: from 0 to 93)<br>
# 31 G1 - first period grade (numeric: from 0 to 20)<br>
# 31 G2 - second period grade (numeric: from 0 to 20)<br>
# 32 G3 - final grade (numeric: from 0 to 20)<br>

# %%
df.loc[:, ['G1', 'G2', 'G3']].dtypes
# Out:
# G1    int64
# G2    int64
# G3    int64
# dtype: object

# %% [markdown]
# ### final_grade column created and the respective sum values were assigned

# %%
df['final_grade'] = df['G1']+df['G2']+df['G3']

# %%
df.loc[:, ['G1', 'G2', 'G3', 'final_grade']].head()
# Out:
#    G1  G2  G3  final_grade
# 0   5   6   6           17
# 1   5   5   6           16
# 2   7   8  10           25
# 3  15  14  15           44
# 4   6  10  10           26

# %%
df.drop(columns = ['G1', 'G2', 'G3'], inplace = True)

# %% [markdown]
# #### the grade columns were dropped

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'final_grade'],
#       dtype='object')

# %%
df.shape
# Out:
# (395, 31)

# %% [markdown]
# ## Hence we added a column and removed the three grade columns as well

# %%
df.head(10)
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu      Mjob  \
# 0       1    1   18        1        1        0     4     4   at_home
# 1       1    1   17        1        1        1     1     1   at_home
# 2       1    1   15        1        0        1     1     1   at_home
# 3       1    1   15        1        1        1     4     2    health
# 4       1    1   16        1        1        1     3     3     other
# 5       1    0   16        1        0        1     4     3  services
# 6       1    0   16        1        0        1     2     2     other
# 7       1    1   17        1        1        0     4     4     other
# 8       1    0   15        1        0        0     3     2  services
# 9       1    0   15        1        1        1     3     4     other
#
#        Fjob  ... internet romantic  famrel  freetime  goout  Dalc  Walc  \
# 0   teacher  ...        0        0       4         3      4     1     1
# 1     other  ...        1        0       5         3      3     1     1
# 2     other  ...        1        0       4         3      2     2     3
# 3  services  ...        1        1       3         2      2     1     1
# 4     other  ...        0        0       4         3      2     1     2
# 5     other  ...        1        0       5         4      2     1     2
# 6     other  ...        1        0       4         4      4     1     1
# 7   teacher  ...        0        0       4         1      4     1     1
# 8     other  ...        1        0       4         2      2     1     1
# 9     other  ...        1        0       5         5      1     1     1
#
#    health  absences  final_grade
# 0       3         6           17
# 1       3         4           16
# 2       3        10           25
# 3       5         2           44
# 4       5         4           26
# 5       5        10           45
# 6       3         0           35
# 7       1         6           17
# 8       1         0           53
# 9       5         0           44
#
# [10 rows x 31 columns]

# %%
df['school'] = np.where(df['school'] == 'GP', 1, 0)## GP---> 1, MS----> 0
df['sex'] = np.where(df['sex'] == 'F', 1, 0) ##F--->1, M--->0
df['address'] = np.where(df['address'] == 'U', 1, 0) # U--->1, R--->0
df['famsize'] = np.where(df['famsize'] == 'GT3', 1, 0)  ## GT3--->1, LE3-->0
df['Pstatus'] = np.where(df['Pstatus'] == 'T', 1, 0)  # T--->1, U--->0
df['schoolsup'] = np.where(df['schoolsup'] == 'yes', 1, 0)  # yes---->1, no--> 0
df['famsup'] = np.where(df['famsup'] == 'yes', 1, 0)
df['paid'] = np.where(df['paid'] == 'yes', 1, 0)
df['activities'] = np.where(df['activities'] == 'yes', 1, 0)
df['nursery'] = np.where(df['nursery'] == 'yes', 1, 0)
df['higher'] = np.where(df['higher'] == 'yes', 1, 0)
df['internet'] = np.where(df['internet'] == 'yes', 1, 0)
df['romantic'] = np.where(df['romantic'] == 'yes', 1, 0)

# %% [markdown]
# #### Converted to binary

# %%
df.T
# Out:
#                  0        1        2         3       4           5       6    \
# school             1        1        1         1       1           1       1
# sex                1        1        1         1       1           0       0
# age               18       17       15        15      16          16      16
# address            1        1        1         1       1           1       1
# famsize            1        1        0         1       1           0       0
# Pstatus            0        1        1         1       1           1       1
# Medu               4        1        1         4       3           4       2
# Fedu               4        1        1         2       3           3       2
# Mjob         at_home  at_home  at_home    health   other    services   other
# Fjob         teacher    other    other  services   other       other   other
# reason        course   course    other      home    home  reputation    home
# guardian      mother   father   mother    mother  father      mother  mother
# traveltime         2        1        1         1       1           1       1
# studytime          2        2        2         3       2           2       2
# failures           0        0        3         0       0           0       0
# schoolsup          1        0        1         0       0           0       0
# famsup             0        1        0         1       1           1       0
# paid               0        0        1         1       1           1       0
# activities         0        0        0         1       0           1       0
# nursery            1        0        1         1       1           1       1
# higher             1        1        1         1       1           1       1
# internet           0        1        1         1       0           1       1
# romantic           0        0        0         1       0           0       0
# famrel             4        5        4         3       4           5       4
# freetime           3        3        3         2       3           4       4
# goout              4        3        2         2       2           2       4
# Dalc               1        1        2         1       1           1       1
# Walc               1        1        3         1       2           2       1
# health             3        3        3         5       5           5       3
# absences           6        4       10         2       4          10       0
# final_grade       17       16       25        44      26          45      35
#
#                  7         8       9    ...      385         386       387  \
# school             1         1       1  ...        0           0         0
# sex                1         0       0  ...        1           1         1
# age               17        15      15  ...       18          18        19
# address            1         1       1  ...        0           0         0
# famsize            1         0       1  ...        1           1         1
# Pstatus            0         0       1  ...        1           1         1
# Medu               4         3       3  ...        2           4         2
# Fedu               4         2       4  ...        2           4         3
# Mjob           other  services   other  ...  at_home     teacher  services
# Fjob         teacher     other   other  ...    other     at_home     other
# reason          home      home    home  ...    other  reputation    course
# guardian      mother    mother  mother  ...   mother      mother    mother
# traveltime         2         1       1  ...        2           3         1
# studytime          2         2       2  ...        3           1         3
# failures           0         0       0  ...        0           0         1
# schoolsup          1         0       0  ...        0           0         0
# famsup             1         1       1  ...        0           1         0
# paid               0         1       1  ...        1           1         0
# activities         0         0       1  ...        0           1         1
# nursery            1         1       1  ...        1           1         0
# higher             1         1       1  ...        1           1         1
# internet           0         1       1  ...        0           1         1
# romantic           0         0       0  ...        0           1         0
# famrel             4         4       5  ...        5           4         5
# freetime           1         2       5  ...        3           4         4
# goout              4         2       1  ...        3           3         2
# Dalc               1         1       1  ...        1           2         1
# Walc               1         1       1  ...        3           2         2
# health             1         1       5  ...        4           5         5
# absences           6         0       0  ...        2           7         0
# final_grade       17        53      44  ...       29          17        12
#
#                   388     389       390       391     392       393      394
# school              0       0         0         0       0         0        0
# sex                 1       1         0         0       0         0        0
# age                18      18        20        17      21        18       19
# address             1       1         1         1       0         0        1
# famsize             0       1         0         0       1         0        0
# Pstatus             1       1         0         1       1         1        1
# Medu                3       1         2         3       1         3        1
# Fedu                1       1         2         1       1         2        1
# Mjob          teacher   other  services  services   other  services    other
# Fjob         services   other  services  services   other     other  at_home
# reason         course  course    course    course  course    course   course
# guardian       mother  mother     other    mother   other    mother   father
# traveltime          1       2         1         2       1         3        1
# studytime           2       2         2         1       1         1        1
# failures            0       1         2         0       3         0        0
# schoolsup           0       0         0         0       0         0        0
# famsup              1       0         1         0       0         0        0
# paid                1       0         1         0       0         0        0
# activities          0       1         0         0       0         0        0
# nursery             1       1         1         0       0         0        1
# higher              1       1         1         1       1         1        1
# internet            1       0         0         1       0         1        1
# romantic            0       0         0         0       0         0        0
# famrel              4       1         5         2       5         4        3
# freetime            3       1         5         4       5         4        2
# goout               4       1         4         5       3         1        3
# Dalc                1       1         4         3       3         3        3
# Walc                1       1         5         4       3         4        3
# health              1       5         4         2       3         5        5
# absences            0       0        11         3       3         0        5
# final_grade        24      11        27        46      25        33       26
#
# [31 rows x 395 columns]

# %% [markdown]
# #### All the binary type data were converted into 1 and 0 according to our requirements

# %%
df.dtypes
# Out:
# school          int32
# sex             int32
# age             int64
# address         int32
# famsize         int32
# Pstatus         int32
# Medu            int64
# Fedu            int64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime      int64
# studytime       int64
# failures        int64
# schoolsup       int32
# famsup          int32
# paid            int32
# activities      int32
# nursery         int32
# higher          int32
# internet        int32
# romantic        int32
# famrel          int64
# freetime        int64
# goout           int64
# Dalc            int64
# Walc            int64
# health          int64
# absences        int64
# final_grade     int64
# dtype: object

# %% [markdown]
# #### Hence we see that even the data types have also been changed

# %%
fig, ax = plt.subplots(figsize = (9,7))
a1 = ax.scatter(df['studytime'], df['final_grade'], c =df['sex'] ,cmap ='winter')
plt.xlabel('studytime------------>', fontsize = 20, color = 'darkblue')
plt.ylabel('final_grade----------->', fontsize = 20, color = 'darkblue')
plt.xticks(fontsize = 10, color = 'darkblue')
plt.yticks(fontsize = 10, color = 'darkblue')
plt.grid(color = 'black', linewidth = 0.3)
ax.legend(*a1.legend_elements(), title = 'sex' , shadow = 45, loc = 'lower right', fontsize = 15)
plt.title("Plot between study time and final_grades", fontsize = 15)
ax.axhline(y = df["final_grade"].mean(), linestyle = "--", linewidth = 2);

# %%
fig, ax = plt.subplots(figsize = (9,7))
plot = sns.boxplot(x = 'studytime', y = 'final_grade', data = df, saturation = 0.7, linewidth = 1, ax = ax)
plt.xlabel('studytime(in hrs)------------>', fontsize = 16, color = 'darkblue')
plt.ylabel('final_grade----------->', fontsize = 16, color = 'darkblue')
plt.xticks(fontsize = 12, color = 'darkblue')
plt.yticks(np.arange(0, 70, 5), fontsize = 12, color = 'darkblue')
plt.grid(color = 'black', linewidth = 0.1)
plot.set_xticklabels(plot.get_xticklabels(), rotation= 90)
plt.title("Plot between study time and final_grades", fontsize = 15)
ax.axhline(y = df["final_grade"].mean(), linestyle = "--", linewidth = 2, color = 'black');
